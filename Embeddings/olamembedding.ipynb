# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = OllamaEmbeddings(model="nomic-embed-text")

# %%
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='nomic-embed-text', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embeddings.embed_documents(["kiran kumar is from shivamoga",
                               "vinay is his brother"])

# %%
r1
# Out:
# [[-0.17162644863128662,
#   0.6234661340713501,
#   -3.4077727794647217,
#   0.4070587754249573,
#   0.0816667377948761,
#   -0.010218769311904907,
#   0.6416347622871399,
#   -0.045125775039196014,
#   -0.5467161536216736,
#   0.1436312347650528,
#   -1.1130099296569824,
#   0.9445666074752808,
#   1.8993372917175293,
#   0.7602053880691528,
#   -0.022470474243164062,
#   -0.24878153204917908,
#   0.9514663219451904,
#   -0.5614153146743774,
#   -0.1450938731431961,
#   1.1848450899124146,
#   -2.3103220462799072,
#   1.1094471216201782,
#   -0.03636553883552551,
#   0.6706696152687073,
#   2.887025833129883,
#   0.452379435300827,
#   0.8483483195304871,
#   0.11343969404697418,
#   -0.5291617512702942,
#   -1.338179111480713,
#   1.8751957416534424,
#   -1.3852683305740356,
#   -0.32984626293182373,
#   -0.6693324446678162,
#   -0.9277820587158203,
#   -0.37180280685424805,
#   1.64858877658844,
#   -0.2557283937931061,
#   -0.0443623885512352,
#   -1.1446419954299927,
# ...

# %%
r1[1]
# Out:
# [0.13560745120048523,
#  -0.4111208915710449,
#  -3.2605414390563965,
#  -0.35035422444343567,
#  0.3514614999294281,
#  -1.396742582321167,
#  0.016020840033888817,
#  -0.44526320695877075,
#  -0.19816410541534424,
#  -0.5343363285064697,
#  -1.3922004699707031,
#  0.9361815452575684,
#  0.916485071182251,
#  0.44110649824142456,
#  0.29395148158073425,
#  -0.04123110696673393,
#  0.07153055816888809,
#  -0.7241743803024292,
#  0.4541855454444885,
#  -0.658021092414856,
#  -1.9468460083007812,
#  0.932559609413147,
#  -0.993929386138916,
#  0.037075065076351166,
#  3.0215249061584473,
#  -0.9208583831787109,
#  -0.7471021413803101,
#  0.30994629859924316,
#  -1.2795850038528442,
#  -0.3129819333553314,
#  2.26580548286438,
#  -0.042089611291885376,
#  0.1398651897907257,
#  0.19094698131084442,
#  -1.2719050645828247,
#  0.022054918110370636,
#  1.4217725992202759,
#  1.3312124013900757,
#  0.37374454736709595,
#  -0.444454550743103,
#  1.1868984699249268,
#  0.6804170608520508,
# ...
